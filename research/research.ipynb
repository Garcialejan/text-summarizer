# %%
import os
os.chdir("..")

from src.text_summarizer.utils.common import read_yaml

# %%
from pathlib import Path
yml = read_yaml(Path("C:/Users/Alejandro/Desktop/Proyectos_personales_github/End_to_end_projects/text-summarizer/params.yaml"))
yml
# Out:
# [2025-11-15 17:56:27,519: INFO: common: yaml file: C:\Users\Alejandro\Desktop\Proyectos_personales_github\End_to_end_projects\text-summarizer\params.yaml loaded successfully]
# ConfigBox({'TrainingArguments': {'num_train_epochs': 1, 'warmup_steps': 500, 'per_device_train_batch_size': 1, 'weight_decay': 0.01, 'logging_steps': 10, 'evaluation_strategy': 'steps', 'eval_steps': 500, 'save_steps': '1e6', 'gradient_accumulation_steps': 16}})

# %%
yml.TrainingArguments.num_train_epochs
# Out:
# 1
